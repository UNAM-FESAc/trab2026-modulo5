# %% [markdown]
# # 🔍 Módulo 5: Herramientas de Investigación
# #### Javier Orduz
# [mywebsiteBDG]:https://img.shields.io/badge/website-jaorduz.github.io-0abeeb?style=plastic
# [mywebsite]: https://jaorduz.github.io/
#
# [mygithubBDG-jaorduz]: https://img.shields.io/badge/jaorduz-repos-blue?logo=github&label=jaorduz&style=plastic
# [mygithub-jaorduz]: https://github.com/jaorduz/
#
# [mygithubBDG-jaorduc]: https://img.shields.io/badge/jaorduc-repos-blue?logo=github&label=jaorduc&style=plastic
# [mygithub-jaorduc]: https://github.com/jaorduc/
#
# [myXprofileBDG]: https://img.shields.io/static/v1?label=Follow&message=jaorduc&color=2ea44f&style=plastic&logo=X&logoColor=black
# [myXprofile]:https://twitter.com/jaorduc
#
# [![website - jaorduz.github.io][mywebsiteBDG]][mywebsite]
# [![Github][mygithubBDG-jaorduz]][mygithub-jaorduz]
# [![Github][mygithubBDG-jaorduc]][mygithub-jaorduc]
# [![Follow @jaorduc][myXprofileBDG]][myXprofile]
#
# ![Version](https://img.shields.io/badge/version-1.0.0-blue)
# ![Python](https://img.shields.io/badge/python-3.11-blue)
# ![License](https://img.shields.io/badge/license-MIT-green)
# ![Status](https://img.shields.io/badge/status-stable-success)
#
# ---
# # Actividad 3: relaciones entre variables
#
# Nombre(s): ______________________________________________________________________________
#
# Número de usuario en Moodle: ______________________________________________________________________________
#
# Fecha: _____________________________________
#
#
# # Instrucciones generales
#
# Esta actividad contiene **3 ejercicios** y tiene un valor total de **9 puntos**.
#
# - No agregue ni elimine celdas.
# - No modifique las celdas de solo lectura.
# - Modifique únicamente las celdas que contienen `# ESCRIBA SU CÓDIGO AQUÍ` y elimine
# ```python
# raise NotImplementedError()
# ```
# - Ejecute las celdas en orden.
# - Los `assert` forman parte de la evaluación automática.
# - Los tests visibles comprueban propiedades básicas; la evaluación incluye comprobaciones adicionales.
# - No escriba valores esperados de forma manual: implemente el procedimiento solicitado.
# - Antes de entregar, reinicie el kernel y ejecute **Run All**.
# - Guarde el notebook con frecuencia.
#
# # ¿Qué haremos?
#
# Crear una variable nueva, compara grupos y explora una relación con una gráfica.

# %%
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt

data_path = 'https://raw.githubusercontent.com/UNAM-FESAc/trab2026-modulo5/main/data/activity_data.csv'
df = pd.read_csv(data_path)
df.head()

# %% [markdown]
# ## 1. Crear una variable de cambio
#
# Calcula `measurement_after - measurement_before` y guarda el resultado en una nueva columna llamada `change`.
#
# Copia, pega y completa el código para que muestre la gráfica.
#
# ```python
# df['________'] = df['________'] - df['________']
# df[['________', '________', '________']].________()
# ```

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# ## 2. Comparar grupos
#
# Calcula la media de `change` para cada `group` y guarda el resultado en `cambio_por_grupo`.
#
# Copia, pega y completa el código para que muestre la gráfica.
#
# ```python
# cambio_por_grupo = df.groupby('___________')['___________'].___________()
# print(___________)
# ```

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# ## 3. Visualizar horas y cambio
#
# Crea una gráfica de dispersión con `hours` en el eje horizontal y `change` en el eje vertical. Guarda el eje en `ax`.
#
# Copie, pegue y complete el código:
# ```python
# ax = df.plot.__________(x='hours', y='change')
# ax.set_title('Horas de exposición y cambio observado')
# ax.set_xlabel('Horas')
# ax.set_ylabel('Cambio')
# plt.tight_layout()
# plt.________()
# ```

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# ## Reflexión
# #### ¡Esta celda no permite escribir!
# En una frase: ¿qué diferencia hay entre observar una asociación entre dos variables y demostrar que una causa la otra?
