# %% [markdown]
# # Actividad 1: análisis sencillo de datos
# Nombre(s): ______________________________________________________________________________
# Número de usuario en Moodle: ______________________________________________________________________________
# Fecha: _____________________________________
#
#
# # Instrucciones generales
#
# Esta actividad contiene **3 ejercicios** y tiene un valor total de **9 puntos**.
#
# - No agregue ni elimine celdas.
# - No modifique las celdas de solo lectura.
# - Modifique únicamente las celdas que contienen `# ESCRIBA SU CÓDIGO AQUÍ` y elimine
# ```python
# raise NotImplementedError()
# ```
# - Ejecute las celdas en orden.
# - Los `assert` forman parte de la evaluación automática.
# - Los tests visibles comprueban propiedades básicas; la evaluación incluye comprobaciones adicionales.
# - No escriba valores esperados de forma manual: implemente el procedimiento solicitado.
# - Antes de entregar, reinicie el kernel y ejecute **Run All**.
# - Guarde el notebook con frecuencia.
#
# # ¿Qué haremos?
#
# Completar las celdas marcadas como respuesta. Usa `pandas` y `matplotlib`.
#
# La actividad trabaja con `research_data.csv` y practica:
#
# 1. cargar datos;
# 2. calcular un resumen por categoría;
# 3. crear una gráfica sencilla.

# %% [markdown]
# ## 1. Cargar los datos
#
# Carga `../data/research_data.csv` en una variable llamada `df` y muestra las primeras cinco filas.

# %%
import pandas as pd
from pathlib import Path

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# ## 2. Resumen por categoría
#
# Calcula el promedio de `value` para cada `category` y guarda el resultado en `promedio_por_categoria`.

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %% [markdown]
# ## 3. Visualización
#
# Crea una gráfica de barras con `promedio_por_categoria`. Incluye un título y nombres para los ejes.
#
# Copia, pega y completa el código para que muestre la gráfica.
#
# ```python
# import matplotlib.pyplot as _______
#
# ax = ______________________.plot(kind='bar')
# ax.set_title('Valor promedio por categoría')
# ax.set_xlabel('Categoría')
# ax.set_ylabel('Valor promedio')
# plt.tight_layout()
# plt.show()
# ```

# %%
# YOUR CODE HERE
raise NotImplementedError()
