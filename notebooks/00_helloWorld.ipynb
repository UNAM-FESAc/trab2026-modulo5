# %%
anio = 2026
print("Hola TRAB", anio)
# Out:
# Hola TRAB 2026

# %%
print("Hola TRAB")

# %%
x = 10
y = 5

x + y
# Out:
# 15

# %%
measurement_before = 42
measurement_after = 51

change = measurement_after - measurement_before

print("El cambio es: ",change)
# Out:
# El cambio es:  9
