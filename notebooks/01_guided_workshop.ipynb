# %% [markdown]
# # Module 5: Guided Workshop
#
# This notebook walks through the foundational concepts of research tools.

# %%
import pandas as pd
import numpy as np

# Load the research data
df = pd.read_csv('../data/research_data.csv')
df.head()
# Out:
#    id     name  value category
# 0   1  Sample1    100    TypeA
# 1   2  Sample2    150    TypeB
# 2   3  Sample3    120    TypeA
# 3   4  Sample4    180    TypeB
# 4   5  Sample5    110    TypeA

# %% [markdown]
# ## Explore the Data

# %%
df.shape
# Out:
# (5, 4)

# %%
df.columns
# Out:
# Index(['id', 'name', 'value', 'category'], dtype='object')

# %%
# Display basic statistics
df.describe()
# Out:
#              id       value
# count  5.000000    5.000000
# mean   3.000000  132.000000
# std    1.581139   32.710854
# min    1.000000  100.000000
# 25%    2.000000  110.000000
# 50%    3.000000  120.000000
# 75%    4.000000  150.000000
# max    5.000000  180.000000
