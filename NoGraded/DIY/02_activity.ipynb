# %% [markdown]
# # Module 5: Activity
#
# Complete the following activities to practice your research tool skills.

# %% [markdown]
# ## Activity 1: Data Analysis
#
# Load the research data and perform basic analysis.

# %%
import pandas as pd

# TODO: Load the research data from '../data/research_data.csv'
df = None

# %% [markdown]
# ## Activity 2: Visualization
#
# Create visualizations to explore patterns in the data.

# %%
# TODO: Create visualizations here
